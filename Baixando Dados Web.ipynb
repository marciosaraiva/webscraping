# %%
import requests

url = 'https://www.globo.com/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

page = requests.get(url, headers=headers)

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="pt-BR"> <head><title>globo.com - Absolutamente tudo sobre not\xc3\xadcias, esportes e entretenimento</title><meta charset="utf-8"><meta http-equiv="x-ua-compatible" content="ie=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1"><link rel="canonical" href="https://www.globo.com/"><meta name="title" content="globo.com - Absolutamente tudo sobre not\xc3\xadcias, esportes e entretenimento"><meta name="description" content="S\xc3\xb3 na globo.com voc\xc3\xaa encontra tudo sobre o conte\xc3\xbado e marcas do Grupo Globo. O melhor acervo de v\xc3\xaddeos online sobre entretenimento, esportes e jornalismo do Brasil"><link rel="preconnect" href="https://s.glbimg.com"><link rel="dns-prefetch" href="https://s.glbimg.com"><link rel="preconnect" href="https://s2.glbimg.com"><link rel="dns-prefetch" href="https://s2.glbimg.com"><link rel="preconnect" href="https://s3.glbimg.com"><link rel="dns-prefetch" href="https://s3.glbimg.com"><li
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="pt-BR">
#  <head>
#   <title>
#    globo.com - Absolutamente tudo sobre notícias, esportes e entretenimento
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge,chrome=1" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://www.globo.com/" rel="canonical"/>
#   <meta content="globo.com - Absolutamente tudo sobre notícias, esportes e entretenimento" name="title"/>
#   <meta content="Só na globo.com você encontra tudo sobre o conteúdo e marcas do Grupo Globo. O melhor acervo de vídeos online sobre entretenimento, esportes e jornalismo do Brasil" name="description"/>
#   <link href="https://s.glbimg.com" rel="preconnect"/>
#   <link href="https://s.glbimg.com" rel="dns-prefetch"/>
#   <link href="https://s2.glbimg.com" rel="preconnect"/>
#   <link href="https://s2.glbimg.com" rel="dns-prefetch"/>
#   <link href="https://s3.glbimg.com" rel="preconnect"/>
# ...

# %%
soup.find_all('p')
# Out:
# [<p>minha conta</p>,
#  <p>ou cadastre-se grátis</p>,
#  <p class="menu-products__list__item__link__text">g1</p>,
#  <p class="menu-products__list__item__link__text">ge</p>,
#  <p class="menu-products__list__item__link__text">cartola fc</p>,
#  <p class="menu-products__list__item__link__text">gshow</p>,
#  <p class="menu-products__list__item__link__text">receitas</p>,
#  <p class="menu-products__list__item__link__text">globoplay</p>,
#  <p class="menu-products__list__item__link__text">techtudo</p>,
#  <p> <svg height="38px" width="192px" xmlns="http://www.w3.org/2000/svg"> <use href="#description-login" xlink:href="#description-login"> </use> </svg> </p>,
#  <p>minha conta</p>,
#  <p>sair</p>,
#  <p class="highlight__title video-grid__container__item__info__title"> Maternidade usa técnica do 'bailão funk' para facilitar parto natural </p>,
#  <p class="highlight__title video-grid__container__item__info__title"> Conká crê em Gil finalista e fala sobre Lumena </p>,
# ...

# %%
soup.find_all('p')[5].get_text()
# Out:
# 'gshow'

# %%
# soup.find_all('p', class_='classe_css') - tag e classe css
# soup.find_all(class_="outer-text") - apenas classe css
# soup.find_all(id="first") - por identificador
# soup.select("div p") - todas os p que estão dentro de divs
'''
p a: Encontra todas as tags a dentro de uma tag p;
body p a: Encontra as tags a dentro de uma tag p dentro da tag body;
html body: Encontra todas as tags body dentro de uma tag html;
p.outer-text: Encontra todas as tags p com uma classe outer-text;
p#first: Encontra todas as tags p com um id first;
body p.outer-text: Encontra quaisquer tags p com uma classe outer-text dentro de uma tag body.
'''
